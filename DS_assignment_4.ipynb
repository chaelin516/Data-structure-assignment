# %% [markdown]
# # 1. LeetCode 225. Implement Stack using Queues

# %%
from collections import deque

class MyStack:
    def __init__(self):
        self.q = deque()

    def push(self, x: int) -> None:
        self.q.append(x)
        for _ in range(len(self.q) - 1):
            self.q.append(self.q.popleft())

    def pop(self) -> int:
        return self.q.popleft()

    def top(self) -> int:
        return self.q[0]

    def empty(self) -> bool:
        return not self.q

# %% [markdown]
# # 2. LeetCode 232. Implement Queue using Stacks

# %%
class MyQueue:
    def __init__(self):
        self.in_stack = []
        self.out_stack = []

    def push(self, x: int) -> None:
        self.in_stack.append(x)

    def pop(self) -> int:
        self.peek()
        return self.out_stack.pop()

    def peek(self) -> int:
        if not self.out_stack:
            while self.in_stack:
                self.out_stack.append(self.in_stack.pop())
        return self.out_stack[-1]

    def empty(self) -> bool:
        return not self.in_stack and not self.out_stack

# %% [markdown]
# # 3. 교재의 큐 연습문제

# %%
#1.
class ListQueue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):
        # 리스트 앞쪽에 삽입 => tail은 리스트의 앞
        self.__queue.insert(0, x)

    def dequeue(self):
        # 리스트 뒤쪽에서 꺼냄 => front는 리스트의 끝
        return self.__queue.pop()

    def front(self):
        # front는 리스트의 끝
        return self.__queue[-1]

    def isEmpty(self) -> bool:
        return len(self.__queue) == 0

    def dequeueAll(self):
        self.__queue.clear()

#2.
from collections import deque

def is_valid_w_dollar_w(s: str) -> bool:
    q = deque()
    i = 0

    # 첫 번째 부분 w를 큐에 저장
    while i < len(s) and s[i] != '$':
        q.append(s[i])
        i += 1

    # '$'가 없거나 마지막이면 False
    if i == len(s) or i == len(s) - 1:
        return False

    i += 1  # '$' 다음 문자부터 검사 시작

    # 두 번째 부분이 큐와 동일한지 확인
    while i < len(s) and q:
        if s[i] != q.popleft():
            return False
        i += 1

    # 큐가 모두 비어야 함
    return len(q) == 0 and i == len(s)

#3.
def copyQueue(a):
    b = LinkedQueue()
    temp = LinkedQueue()

    # a를 temp와 b로 복사
    while not a.isEmpty():
        x = a.dequeue()
        b.enqueue(x)
        temp.enqueue(x)

    # a 복구
    while not temp.isEmpty():
        a.enqueue(temp.dequeue())

    return b

#4.
from collections import deque

class StackUsingQueues:
    def __init__(self):
        self.q1 = deque()
        self.q2 = deque()

    def push(self, x):
        self.q2.append(x)
        while self.q1:
            self.q2.append(self.q1.popleft())
        self.q1, self.q2 = self.q2, self.q1

    def pop(self):
        if self.q1:
            return self.q1.popleft()
        raise IndexError("pop from empty stack")

#5.
class QueueUsingStacks:
    def __init__(self):
        self.s1 = []
        self.s2 = []

    def enqueue(self, x):
        self.s1.append(x)

    def dequeue(self):
        if not self.s2:
            while self.s1:
                self.s2.append(self.s1.pop())
        if self.s2:
            return self.s2.pop()
        raise IndexError("dequeue from empty queue")
#6.
# enqueueFront(), enqueueRear(): O(1)

# dequeueFront(), dequeueRear(): O(1)

#7.
# enqueueRear(), dequeueFront() → O(1)

# enqueueFront() → O(n) (노드를 따라가야 함)

# dequeueRear() → O(n) (끝 노드의 이전 노드를 찾아야 함)

#8.
class Deque:
    def __init__(self):
        self.__deque = []

    def enqueueFront(self, x):
        self.__deque.insert(0, x)  # 앞에 삽입

    def enqueueRear(self, x):
        self.__deque.append(x)  # 뒤에 삽입

    def dequeueFront(self):
        if self.isEmpty():
            return None
        return self.__deque.pop(0)  # 앞에서 제거

    def dequeueRear(self):
        if self.isEmpty():
            return None
        return self.__deque.pop()  # 뒤에서 제거

    def front(self):
        if self.isEmpty():
            return None
        return self.__deque[0]

    def rear(self):
        if self.isEmpty():
            return None
        return self.__deque[-1]

    def isEmpty(self) -> bool:
        return len(self.__deque) == 0

    def dequeueAll(self):
        self.__deque.clear()

    def printDeque(self):
        print("Deque from front: ", end='')
        for item in self.__deque:
            print(item, end=' ')
        print()
